# %%
import numpy as np
import pandas as pd

# %%
cd1 = pd.read_csv("/home/feczk001/shared/projects/FEZ_USERS/feczk001/UPPS_ABCD_FRF/code/jacob/Temp_fixed_list_ARMS1_merged.csv")
cd2 = pd.read_csv("/home/feczk001/shared/projects/FEZ_USERS/feczk001/UPPS_ABCD_FRF/code/jacob/Temp_fixed_list_ARMS2_merged.csv")

# %%
cd1.shape
# Out:
# (3337, 25)

# %%
cd2.shape
# Out:
# (3234, 25)

# %%
cd1.head()
# Out:
#   src_subject_id.baseline_year_1_arm_1.x  X  \
# 0                       NDAR_INV003RTV85  1
# 1                       NDAR_INV007W6H7B  3
# 2                       NDAR_INV00BD7VDC  4
# 3                       NDAR_INV00HEV6HB  6
# 4                       NDAR_INV00LH735Y  8
#
#    dataset_id.baseline_year_1_arm_1.x  interview_age.baseline_year_1_arm_1.x  \
# 0                               47437                                    131
# 1                               47437                                    126
# 2                               47437                                    112
# 3                               47437                                    124
# 4                               47437                                    109
#
#   sex.baseline_year_1_arm_1.x  bis_y_ss_bas_rr.baseline_year_1_arm_1  \
# 0                           F                                      9
# 1                           M                                      5
# 2                           M                                      6
# 3                           M                                     13
# 4                           M                                     12
#
#    bis_y_ss_bas_drive.baseline_year_1_arm_1  \
# 0                                         2
# 1                                         1
# 2                                         2
# 3                                         4
# 4                                         3
#
#    bis_y_ss_bas_fs.baseline_year_1_arm_1  \
# 0                                      6
# 1                                      1
# 2                                      5
# 3                                      7
# 4                                      6
#
#    bis_y_ss_bis_sum.baseline_year_1_arm_1  \
# 0                                       2
# 1                                       6
# 2                                      11
# 3                                       4
# 4                                       2
#
#    upps_y_ss_negative_urgency.baseline_year_1_arm_1  ...  \
# 0                                                10  ...
# 1                                                 6  ...
# 2                                                 8  ...
# 3                                                12  ...
# 4                                                 5  ...
#
#    nihtbx_flanker_agecorrected.baseline_year_1_arm_1  \
# 0                                                101
# 1                                                 92
# 2                                                116
# 3                                                 74
# 4                                                 88
#
#    nihtbx_list_agecorrected.baseline_year_1_arm_1  \
# 0                                             100
# 1                                             107
# 2                                             145
# 3                                              93
# 4                                              82
#
#    nihtbx_cardsort_agecorrected.baseline_year_1_arm_1  \
# 0                                                 86
# 1                                                103
# 2                                                 90
# 3                                                 94
# 4                                                 81
#
#    nihtbx_pattern_agecorrected.baseline_year_1_arm_1  \
# 0                                                103
# 1                                                 95
# 2                                                117
# 3                                                103
# 4                                                 56
#
#    nihtbx_picture_agecorrected.baseline_year_1_arm_1  \
# 0                                                106
# 1                                                119
# 2                                                116
# 3                                                 99
# 4                                                116
#
#    nihtbx_reading_agecorrected.baseline_year_1_arm_1  \
# 0                                                 81
# 1                                                110
# 2                                                 85
# 3                                                110
# 4                                                 85
#
#    nihtbx_fluidcomp_agecorrected.baseline_year_1_arm_1  \
# 0                                               98.0
# 1                                              104.0
# 2                                              127.0
# 3                                               88.0
# 4                                               75.0
#
#    nihtbx_cryst_agecorrected.baseline_year_1_arm_1  \
# 0                                            102.0
# 1                                            119.0
# 2                                             90.0
# 3                                            101.0
# 4                                             90.0
#
#    nihtbx_totalcomp_agecorrected.baseline_year_1_arm_1  community
# 0                                               99.0            7
# 1                                              114.0            7
# 2                                              110.0            5
# 3                                               93.0            1
# 4                                               79.0            8
#
# [5 rows x 25 columns]

# %%
cd1 = cd1.filter(regex=r'^bis|^upps|^community$', axis=1)
cd2 = cd2.filter(regex=r'^bis|^upps|^community$', axis=1)

# %%
cd1.head()
# Out:
#    bis_y_ss_bas_rr.baseline_year_1_arm_1  \
# 0                                      9
# 1                                      5
# 2                                      6
# 3                                     13
# 4                                     12
#
#    bis_y_ss_bas_drive.baseline_year_1_arm_1  \
# 0                                         2
# 1                                         1
# 2                                         2
# 3                                         4
# 4                                         3
#
#    bis_y_ss_bas_fs.baseline_year_1_arm_1  \
# 0                                      6
# 1                                      1
# 2                                      5
# 3                                      7
# 4                                      6
#
#    bis_y_ss_bis_sum.baseline_year_1_arm_1  \
# 0                                       2
# 1                                       6
# 2                                      11
# 3                                       4
# 4                                       2
#
#    upps_y_ss_negative_urgency.baseline_year_1_arm_1  \
# 0                                                10
# 1                                                 6
# 2                                                 8
# 3                                                12
# 4                                                 5
#
#    upps_y_ss_positive_urgency.baseline_year_1_arm_1  \
# 0                                                 7
# 1                                                 8
# 2                                                 8
# 3                                                11
# 4                                                 4
#
#    upps_y_ss_lack_of_planning.baseline_year_1_arm_1  \
# 0                                                11
# 1                                                11
# 2                                                 7
# 3                                                12
# 4                                                 6
#
#    upps_y_ss_sensation_seeking.baseline_year_1_arm_1  \
# 0                                                  7
# 1                                                  6
# 2                                                 11
# 3                                                  6
# 4                                                 11
#
#    upps_y_ss_lack_of_perseverance.baseline_year_1_arm_1  community
# 0                                                 10             7
# 1                                                 10             7
# 2                                                  6             5
# 3                                                  7             1
# 4                                                  5             8

# %%
cd2.head()
# Out:
#    bis_y_ss_bas_rr.baseline_year_1_arm_1  \
# 0                                     12
# 1                                      7
# 2                                     15
# 3                                     13
# 4                                     11
#
#    bis_y_ss_bas_drive.baseline_year_1_arm_1  \
# 0                                         9
# 1                                         3
# 2                                         6
# 3                                         0
# 4                                         3
#
#    bis_y_ss_bas_fs.baseline_year_1_arm_1  \
# 0                                      3
# 1                                      3
# 2                                     12
# 3                                      3
# 4                                     10
#
#    bis_y_ss_bis_sum.baseline_year_1_arm_1  \
# 0                                       8
# 1                                       8
# 2                                      10
# 3                                      12
# 4                                      11
#
#    upps_y_ss_negative_urgency.baseline_year_1_arm_1  \
# 0                                                 9
# 1                                                 6
# 2                                                12
# 3                                                 6
# 4                                                11
#
#    upps_y_ss_positive_urgency.baseline_year_1_arm_1  \
# 0                                                 9
# 1                                                 5
# 2                                                11
# 3                                                 4
# 4                                                 8
#
#    upps_y_ss_lack_of_planning.baseline_year_1_arm_1  \
# 0                                                 9
# 1                                                 7
# 2                                                 8
# 3                                                 6
# 4                                                 9
#
#    upps_y_ss_sensation_seeking.baseline_year_1_arm_1  \
# 0                                                 13
# 1                                                 13
# 2                                                 15
# 3                                                 14
# 4                                                 15
#
#    upps_y_ss_lack_of_perseverance.baseline_year_1_arm_1  community
# 0                                                  9             4
# 1                                                  8             1
# 2                                                  6             5
# 3                                                  6             6
# 4                                                  6             1

# %%
#cd1 = cd1.drop(['nihtbx_list_agecorrected.baseline_year_1_arm_1'], axis=1)
#cd2 = cd2.drop(['nihtbx_list_agecorrected.baseline_year_1_arm_1'], axis=1)

# %%
cd1.shape
# Out:
# (3337, 10)

# %%
cd2.shape
# Out:
# (3234, 10)

# %%
def remove_small_communities(df, community_column, threshold=100):
    community_counts = df[community_column].value_counts()
    mask = df[community_column].isin(community_counts[community_counts >= threshold].index)
    filtered_df = df[mask]
    return filtered_df

cd1 = remove_small_communities(cd1, 'community')
value_counts_cd1 = cd1['community'].value_counts()
print(value_counts_cd1)
# Out:
# community
# 2    661
# 1    631
# 4    449
# 3    415
# 5    327
# 6    267
# 7    184
# 8    108
# 9    104
# Name: count, dtype: int64

# %%
cd2 = remove_small_communities(cd2, 'community')
value_counts_cd2 = cd2['community'].value_counts()
print(value_counts_cd2)
# Out:
# community
# 1    818
# 2    538
# 4    518
# 3    462
# 6    367
# 5    352
# 7    121
# Name: count, dtype: int64

# %%
cd1.shape
# Out:
# (3146, 10)

# %%
cd2.shape
# Out:
# (3176, 10)

# %%
cd1.head()
# Out:
#    bis_y_ss_bas_rr.baseline_year_1_arm_1  \
# 0                                      9
# 1                                      5
# 2                                      6
# 3                                     13
# 4                                     12
#
#    bis_y_ss_bas_drive.baseline_year_1_arm_1  \
# 0                                         2
# 1                                         1
# 2                                         2
# 3                                         4
# 4                                         3
#
#    bis_y_ss_bas_fs.baseline_year_1_arm_1  \
# 0                                      6
# 1                                      1
# 2                                      5
# 3                                      7
# 4                                      6
#
#    bis_y_ss_bis_sum.baseline_year_1_arm_1  \
# 0                                       2
# 1                                       6
# 2                                      11
# 3                                       4
# 4                                       2
#
#    upps_y_ss_negative_urgency.baseline_year_1_arm_1  \
# 0                                                10
# 1                                                 6
# 2                                                 8
# 3                                                12
# 4                                                 5
#
#    upps_y_ss_positive_urgency.baseline_year_1_arm_1  \
# 0                                                 7
# 1                                                 8
# 2                                                 8
# 3                                                11
# 4                                                 4
#
#    upps_y_ss_lack_of_planning.baseline_year_1_arm_1  \
# 0                                                11
# 1                                                11
# 2                                                 7
# 3                                                12
# 4                                                 6
#
#    upps_y_ss_sensation_seeking.baseline_year_1_arm_1  \
# 0                                                  7
# 1                                                  6
# 2                                                 11
# 3                                                  6
# 4                                                 11
#
#    upps_y_ss_lack_of_perseverance.baseline_year_1_arm_1  community
# 0                                                 10             7
# 1                                                 10             7
# 2                                                  6             5
# 3                                                  7             1
# 4                                                  5             8

# %%
cd2.head()
# Out:
#    bis_y_ss_bas_rr.baseline_year_1_arm_1  \
# 0                                     12
# 1                                      7
# 2                                     15
# 3                                     13
# 4                                     11
#
#    bis_y_ss_bas_drive.baseline_year_1_arm_1  \
# 0                                         9
# 1                                         3
# 2                                         6
# 3                                         0
# 4                                         3
#
#    bis_y_ss_bas_fs.baseline_year_1_arm_1  \
# 0                                      3
# 1                                      3
# 2                                     12
# 3                                      3
# 4                                     10
#
#    bis_y_ss_bis_sum.baseline_year_1_arm_1  \
# 0                                       8
# 1                                       8
# 2                                      10
# 3                                      12
# 4                                      11
#
#    upps_y_ss_negative_urgency.baseline_year_1_arm_1  \
# 0                                                 9
# 1                                                 6
# 2                                                12
# 3                                                 6
# 4                                                11
#
#    upps_y_ss_positive_urgency.baseline_year_1_arm_1  \
# 0                                                 9
# 1                                                 5
# 2                                                11
# 3                                                 4
# 4                                                 8
#
#    upps_y_ss_lack_of_planning.baseline_year_1_arm_1  \
# 0                                                 9
# 1                                                 7
# 2                                                 8
# 3                                                 6
# 4                                                 9
#
#    upps_y_ss_sensation_seeking.baseline_year_1_arm_1  \
# 0                                                 13
# 1                                                 13
# 2                                                 15
# 3                                                 14
# 4                                                 15
#
#    upps_y_ss_lack_of_perseverance.baseline_year_1_arm_1  community
# 0                                                  9             4
# 1                                                  8             1
# 2                                                  6             5
# 3                                                  6             6
# 4                                                  6             1

# %%
#cd1.columns = cd1.columns.str.extract(r'bis_y_ss_bas\_(.+?)\.baseline', expand=False)

# %%
cd1.head()
# Out:
#    bis_y_ss_bas_rr.baseline_year_1_arm_1  \
# 0                                      9
# 1                                      5
# 2                                      6
# 3                                     13
# 4                                     12
#
#    bis_y_ss_bas_drive.baseline_year_1_arm_1  \
# 0                                         2
# 1                                         1
# 2                                         2
# 3                                         4
# 4                                         3
#
#    bis_y_ss_bas_fs.baseline_year_1_arm_1  \
# 0                                      6
# 1                                      1
# 2                                      5
# 3                                      7
# 4                                      6
#
#    bis_y_ss_bis_sum.baseline_year_1_arm_1  \
# 0                                       2
# 1                                       6
# 2                                      11
# 3                                       4
# 4                                       2
#
#    upps_y_ss_negative_urgency.baseline_year_1_arm_1  \
# 0                                                10
# 1                                                 6
# 2                                                 8
# 3                                                12
# 4                                                 5
#
#    upps_y_ss_positive_urgency.baseline_year_1_arm_1  \
# 0                                                 7
# 1                                                 8
# 2                                                 8
# 3                                                11
# 4                                                 4
#
#    upps_y_ss_lack_of_planning.baseline_year_1_arm_1  \
# 0                                                11
# 1                                                11
# 2                                                 7
# 3                                                12
# 4                                                 6
#
#    upps_y_ss_sensation_seeking.baseline_year_1_arm_1  \
# 0                                                  7
# 1                                                  6
# 2                                                 11
# 3                                                  6
# 4                                                 11
#
#    upps_y_ss_lack_of_perseverance.baseline_year_1_arm_1  community
# 0                                                 10             7
# 1                                                 10             7
# 2                                                  6             5
# 3                                                  7             1
# 4                                                  5             8

# %%
cd2.head()
# Out:
#    bis_y_ss_bas_rr.baseline_year_1_arm_1  \
# 0                                     12
# 1                                      7
# 2                                     15
# 3                                     13
# 4                                     11
#
#    bis_y_ss_bas_drive.baseline_year_1_arm_1  \
# 0                                         9
# 1                                         3
# 2                                         6
# 3                                         0
# 4                                         3
#
#    bis_y_ss_bas_fs.baseline_year_1_arm_1  \
# 0                                      3
# 1                                      3
# 2                                     12
# 3                                      3
# 4                                     10
#
#    bis_y_ss_bis_sum.baseline_year_1_arm_1  \
# 0                                       8
# 1                                       8
# 2                                      10
# 3                                      12
# 4                                      11
#
#    upps_y_ss_negative_urgency.baseline_year_1_arm_1  \
# 0                                                 9
# 1                                                 6
# 2                                                12
# 3                                                 6
# 4                                                11
#
#    upps_y_ss_positive_urgency.baseline_year_1_arm_1  \
# 0                                                 9
# 1                                                 5
# 2                                                11
# 3                                                 4
# 4                                                 8
#
#    upps_y_ss_lack_of_planning.baseline_year_1_arm_1  \
# 0                                                 9
# 1                                                 7
# 2                                                 8
# 3                                                 6
# 4                                                 9
#
#    upps_y_ss_sensation_seeking.baseline_year_1_arm_1  \
# 0                                                 13
# 1                                                 13
# 2                                                 15
# 3                                                 14
# 4                                                 15
#
#    upps_y_ss_lack_of_perseverance.baseline_year_1_arm_1  community
# 0                                                  9             4
# 1                                                  8             1
# 2                                                  6             5
# 3                                                  6             6
# 4                                                  6             1

# %%
#cd1 = cd1.rename(columns={cd1.columns[cd1.columns.isnull()][0]: 'community'})
#cd2 = cd2.rename(columns={cd2.columns[cd2.columns.isnull()][0]: 'community'})

# %%
cd1.head()
# Out:
#    bis_y_ss_bas_rr.baseline_year_1_arm_1  \
# 0                                      9
# 1                                      5
# 2                                      6
# 3                                     13
# 4                                     12
#
#    bis_y_ss_bas_drive.baseline_year_1_arm_1  \
# 0                                         2
# 1                                         1
# 2                                         2
# 3                                         4
# 4                                         3
#
#    bis_y_ss_bas_fs.baseline_year_1_arm_1  \
# 0                                      6
# 1                                      1
# 2                                      5
# 3                                      7
# 4                                      6
#
#    bis_y_ss_bis_sum.baseline_year_1_arm_1  \
# 0                                       2
# 1                                       6
# 2                                      11
# 3                                       4
# 4                                       2
#
#    upps_y_ss_negative_urgency.baseline_year_1_arm_1  \
# 0                                                10
# 1                                                 6
# 2                                                 8
# 3                                                12
# 4                                                 5
#
#    upps_y_ss_positive_urgency.baseline_year_1_arm_1  \
# 0                                                 7
# 1                                                 8
# 2                                                 8
# 3                                                11
# 4                                                 4
#
#    upps_y_ss_lack_of_planning.baseline_year_1_arm_1  \
# 0                                                11
# 1                                                11
# 2                                                 7
# 3                                                12
# 4                                                 6
#
#    upps_y_ss_sensation_seeking.baseline_year_1_arm_1  \
# 0                                                  7
# 1                                                  6
# 2                                                 11
# 3                                                  6
# 4                                                 11
#
#    upps_y_ss_lack_of_perseverance.baseline_year_1_arm_1  community
# 0                                                 10             7
# 1                                                 10             7
# 2                                                  6             5
# 3                                                  7             1
# 4                                                  5             8

# %%
cd2.head()
# Out:
#    bis_y_ss_bas_rr.baseline_year_1_arm_1  \
# 0                                     12
# 1                                      7
# 2                                     15
# 3                                     13
# 4                                     11
#
#    bis_y_ss_bas_drive.baseline_year_1_arm_1  \
# 0                                         9
# 1                                         3
# 2                                         6
# 3                                         0
# 4                                         3
#
#    bis_y_ss_bas_fs.baseline_year_1_arm_1  \
# 0                                      3
# 1                                      3
# 2                                     12
# 3                                      3
# 4                                     10
#
#    bis_y_ss_bis_sum.baseline_year_1_arm_1  \
# 0                                       8
# 1                                       8
# 2                                      10
# 3                                      12
# 4                                      11
#
#    upps_y_ss_negative_urgency.baseline_year_1_arm_1  \
# 0                                                 9
# 1                                                 6
# 2                                                12
# 3                                                 6
# 4                                                11
#
#    upps_y_ss_positive_urgency.baseline_year_1_arm_1  \
# 0                                                 9
# 1                                                 5
# 2                                                11
# 3                                                 4
# 4                                                 8
#
#    upps_y_ss_lack_of_planning.baseline_year_1_arm_1  \
# 0                                                 9
# 1                                                 7
# 2                                                 8
# 3                                                 6
# 4                                                 9
#
#    upps_y_ss_sensation_seeking.baseline_year_1_arm_1  \
# 0                                                 13
# 1                                                 13
# 2                                                 15
# 3                                                 14
# 4                                                 15
#
#    upps_y_ss_lack_of_perseverance.baseline_year_1_arm_1  community
# 0                                                  9             4
# 1                                                  8             1
# 2                                                  6             5
# 3                                                  6             6
# 4                                                  6             1

# %%
melted_cd1 = pd.melt(cd1, id_vars='community', var_name='metric', value_name='mean')
melted_cd2 = pd.melt(cd2, id_vars='community', var_name='metric', value_name='mean')

# %%
melted_cd1
# Out:
#        community                                             metric  mean
# 0              7              bis_y_ss_bas_rr.baseline_year_1_arm_1     9
# 1              7              bis_y_ss_bas_rr.baseline_year_1_arm_1     5
# 2              5              bis_y_ss_bas_rr.baseline_year_1_arm_1     6
# 3              1              bis_y_ss_bas_rr.baseline_year_1_arm_1    13
# 4              8              bis_y_ss_bas_rr.baseline_year_1_arm_1    12
# ...          ...                                                ...   ...
# 28309          4  upps_y_ss_lack_of_perseverance.baseline_year_1...     7
# 28310          2  upps_y_ss_lack_of_perseverance.baseline_year_1...     7
# 28311          1  upps_y_ss_lack_of_perseverance.baseline_year_1...     4
# 28312          4  upps_y_ss_lack_of_perseverance.baseline_year_1...     5
# 28313          1  upps_y_ss_lack_of_perseverance.baseline_year_1...     6
#
# [28314 rows x 3 columns]

# %%
melted_cd2
# Out:
#        community                                             metric  mean
# 0              4              bis_y_ss_bas_rr.baseline_year_1_arm_1    12
# 1              1              bis_y_ss_bas_rr.baseline_year_1_arm_1     7
# 2              5              bis_y_ss_bas_rr.baseline_year_1_arm_1    15
# 3              6              bis_y_ss_bas_rr.baseline_year_1_arm_1    13
# 4              1              bis_y_ss_bas_rr.baseline_year_1_arm_1    11
# ...          ...                                                ...   ...
# 28579          2  upps_y_ss_lack_of_perseverance.baseline_year_1...     8
# 28580          5  upps_y_ss_lack_of_perseverance.baseline_year_1...     6
# 28581          2  upps_y_ss_lack_of_perseverance.baseline_year_1...     5
# 28582          1  upps_y_ss_lack_of_perseverance.baseline_year_1...     7
# 28583          3  upps_y_ss_lack_of_perseverance.baseline_year_1...     5
#
# [28584 rows x 3 columns]

# %%
grouped_cd1 = melted_cd1.groupby(['community', 'metric'])['mean'].mean().reset_index()
grouped_cd2 = melted_cd2.groupby(['community', 'metric'])['mean'].mean().reset_index()

# %%
grouped_cd1
# Out:
#     community                                             metric       mean
# 0           1           bis_y_ss_bas_drive.baseline_year_1_arm_1   2.852615
# 1           1              bis_y_ss_bas_fs.baseline_year_1_arm_1   5.935024
# 2           1              bis_y_ss_bas_rr.baseline_year_1_arm_1  10.606973
# 3           1             bis_y_ss_bis_sum.baseline_year_1_arm_1   9.630745
# 4           1  upps_y_ss_lack_of_perseverance.baseline_year_1...   6.857369
# ..        ...                                                ...        ...
# 76          9  upps_y_ss_lack_of_perseverance.baseline_year_1...   6.432692
# 77          9   upps_y_ss_lack_of_planning.baseline_year_1_arm_1   8.365385
# 78          9   upps_y_ss_negative_urgency.baseline_year_1_arm_1   8.240385
# 79          9   upps_y_ss_positive_urgency.baseline_year_1_arm_1   6.490385
# 80          9  upps_y_ss_sensation_seeking.baseline_year_1_arm_1   9.278846
#
# [81 rows x 3 columns]

# %%
grouped_cd2
# Out:
#     community                                             metric       mean
# 0           1           bis_y_ss_bas_drive.baseline_year_1_arm_1   2.850856
# 1           1              bis_y_ss_bas_fs.baseline_year_1_arm_1   5.212714
# 2           1              bis_y_ss_bas_rr.baseline_year_1_arm_1  10.260391
# 3           1             bis_y_ss_bis_sum.baseline_year_1_arm_1   8.850856
# 4           1  upps_y_ss_lack_of_perseverance.baseline_year_1...   6.877751
# ..        ...                                                ...        ...
# 58          7  upps_y_ss_lack_of_perseverance.baseline_year_1...   7.132231
# 59          7   upps_y_ss_lack_of_planning.baseline_year_1_arm_1   8.487603
# 60          7   upps_y_ss_negative_urgency.baseline_year_1_arm_1   7.975207
# 61          7   upps_y_ss_positive_urgency.baseline_year_1_arm_1   6.347107
# 62          7  upps_y_ss_sensation_seeking.baseline_year_1_arm_1  10.033058
#
# [63 rows x 3 columns]

# %%
def calculate_mae(grouped_cd1, grouped_cd2, community1, community2):
    df1 = grouped_cd1[grouped_cd1['community'] == community1]
    df2 = grouped_cd2[grouped_cd2['community'] == community2]
    merged_df = pd.merge(df1, df2, on='metric', suffixes=('_cd1', '_cd2'))
    merged_df['abs_diff'] = (merged_df['mean_cd1'] - merged_df['mean_cd2']).abs()
    mae = merged_df['abs_diff'].mean()
    return mae

# %%
community1 = 4
community2 = 5

mae = calculate_mae(grouped_cd1, grouped_cd2, community1, community2)
print(f"The MAE between community {community1} in grouped_cd1 (ARMS1) and community {community2} in grouped_cd2 (ARMS2) is {mae:.2f}")
# Out:
# The MAE between community 4 in grouped_cd1 (ARMS1) and community 5 in grouped_cd2 (ARMS2) is 0.26
